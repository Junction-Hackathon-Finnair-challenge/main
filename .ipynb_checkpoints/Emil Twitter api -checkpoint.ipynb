# %%
import twitter
from tqdm import tqdm
from copy import copy
from datetime import datetime
from time import strptime
import pandas as pd
import nltk
import numpy as np
from enum import Enum

# %%
api = twitter.Api(consumer_key='USctDCgnlL3bNRB6UuXn7d236',
                  consumer_secret='J2VViasvzh3joWrl8sHicoKLnHcjtWk9mM7O9wsieWyqy4W1PL',
                  access_token_key='782531360-ldm9KTYfSwyKXIq4Axh9Op6fDP0IarPCuIl6xzkh',
                  access_token_secret='vKDEmonUAxvL1M1YGvMXDL6OfNwvKgzTD9Se6qKsLRnjT')
api.VerifyCredentials()
# Out:
# User(ID=782531360, ScreenName=bonlime)

# %%
airports_data = pd.read_csv('airports.csv')
airports_data.city.fillna(value='')
cities_set = set([str(i).lower() for i in airports_data['city'].values])
icao_set = set(airports_data['icao'])
iata_set = set(airports_data['iata'])
#airports_data.head()
key_words = ['terrorist attack', 'explosion in the airport','labour strike','union strike',]
event_dict ={'terrorist attack':EVENT_TYPE.TERRORIST_ATTACK,
             'explosion in the airport':EVENT_TYPE.TERRORIST_ATTACK,
             'labour strike':EVENT_TYPE.LABOUR_STRIKE}
# Out:
#   File "<ipython-input-606-4250ad40ba28>", line 10
#     'labour strike':EVENT_TYPE.LABOUR_STRIKE}
#                   ^
# SyntaxError: invalid syntax

# %%
class Mention():
    def __init__(self,status_dict):
        self.datetime_happened = None
        self.datetime_reported = None
        self.longitude = None
        self.lattitude = None
        self.type = None
        self.airport_id = None
        self.city_name = None
        self.country_name = None
        self.raw_description = None
        
        
        self.datetime_reported = pd.Timestamp.strptime(status_dict['created_at'],
                                               '%a %b %d %H:%M:%S +0000 %Y').timestamp()
        if 'utc_offset' in status_dict['user']:
            self.datetime_reported += status_dict['user']['utc_offset']
        
        if 'location' in status_dict['user']:
            self.city_name = status_dict['user']['location'].split(',')[0]
        if 'place' in status_dict:
            if status_dict['place']['place_type'] == 'city':
                if self.city_name:
                    pass
                    #print('overwriting city {} with {}'.format(self.city_name,status_dict['place']['name']))
                self.city_name = status_dict['place']['name']
                # self.country_name = status_dict['place']['full_name'].split(',')[1].strip() в презе не нужно
            if status_dict['place']['place_type'] == 'country':
                pass # не нужно для презы
            if 'bounding_box' in status_dict['place']:
                self.longitude = (status_dict['place']['bounding_box']['coordinates'][0][2][0]+ \
                                  status_dict['place']['bounding_box']['coordinates'][0][3][0])/2.0
                self.lattitude = (status_dict['place']['bounding_box']['coordinates'][0][2][1]+ \
                                  status_dict['place']['bounding_box']['coordinates'][0][3][1])/2.0 # ??
        self.raw_description = status_dict['text']
        tokenized_text_set = set(nltk.word_tokenize(self.raw_description.lower()))
        cities_in_text = list(tokenized_text_set & cities_set)
        if cities_in_text:
            self.city_name = cities_in_text[0]
        airports_in_text = list( tokenized_text_set & (icao_set | iata_set) ) 
        if airports_in_text:
            self.airport_id = airports_in_text[0]
        self.type = status_dict['type']
    def print_self(self):
        print("datetime_happened {}".format(self.datetime_happened))
        print("datetime_reported {}".format(self.datetime_reported))
        print("longitude         {}".format(self.longitude))
        print("lattitude         {}".format(self.lattitude))
        print("type              {}".format(self.type))
        print("airport_id        {}".format(self.airport_id))
        print("city_name         {}".format(self.city_name))
        print("country_name      {}".format(self.country_name))
        print("raw_description   {}".format(self.raw_description))

# %%
def parse_twitter(key_words):    
    all_res = []
    num_iterations = 5 # на практике это слишком много и не нужно
    #event_dict ={'terrorist attack':EVENT_TYPE.TERRORIST_ATTACK,'labour_strike':EVENT_TYPE.LABOUR_STRIKE}
    for key in key_words:
        print("collecting data for '{}' keyword".format(key))
        all_data = api.GetSearch(term=key,count=100,result_type='recent')
        last_id = all_data[-1].AsDict()['id']
        for i in tqdm(range(num_iterations)): # заменить на 50
            all_data.extend(api.GetSearch(term=key,count=100,result_type='recent',max_id=last_id-1))
            last_id = all_data[-1].AsDict()['id']
        #all_res.append([])
        for tweet in all_data:
            if ('retweeted_status' not in tweet.AsDict().keys()) and ('quoted_status' not in tweet.AsDict().keys()):
                dict_tweet = tweet.AsDict()
                dict_tweet['type'] = event_dict[key]
                all_res.append(Mention(dict_tweet))
        #print('{}/{} tweets are not retweets'.format(len(all_res[-1]),num_iterations*100))
    
    return all_res
def delete_last_statuses(num_to_delete):
    for stat_id in [status.AsDict()['id'] for status in api.GetUserTimeline(count=num_to_delete)]:
        api.DestroyStatus(stat_id)
def make_post(text):
    api.PostUpdate(text + '    randseed:'+ str(np.random.randint(1000)))

# %%
all_mention = parse_twitter(key_words)
# Out:
# collecting data for 'terrorist attack' keyword
# 100%|██████████| 5/5 [00:02<00:00,  2.19it/s]
# collecting data for 'labour strike' keyword
# 100%|██████████| 5/5 [00:02<00:00,  2.34it/s]

# %%
all_mention[119].print_self()
# Out:
# datetime_happened None
# datetime_reported 1511421691.0
# longitude         None
# lattitude         None
# type              EVENT_TYPE.LABOUR_STRIKE
# airport_id        None
# city_name         None
# country_name      None
# raw_description   https://t.co/PWsR6FaVfz
#
# #Brexit #Budget2017 #UniversalCredit  #budgetday2017 #PMGQs #England #UniversalCreidt… https://t.co/bTSPiOLYcq

# %%
for m in all_mention:
    print(m.print_self())
    print("")
# Out:
# datetime_happened None
# datetime_reported 1511651584.0
# longitude         None
# lattitude         None
# type              EVENT_TYPE.TERRORIST_ATTACK
# airport_id        None
# city_name         Cambridge
# country_name      None
# raw_description   @Reece6_88 @AntBrolia He didnt Celebrate for Cause of the terrorist Attack in Egypt https://t.co/dFqux0cM8G
# None
# datetime_happened None
# datetime_reported 1511647928.0
# longitude         None
# lattitude         None
# type              EVENT_TYPE.TERRORIST_ATTACK
# airport_id        None
# city_name         #WHU
# country_name      None
# raw_description   The terrorist attack in the Sinai had nothing to do with ‘poverty’ @bbcnews . It has to do purely with deranged minds of Islamist psychos
# None
# datetime_happened None
# datetime_reported 1511647872.0
# longitude         None
# lattitude         None
# type              EVENT_TYPE.TERRORIST_ATTACK
# airport_id        None
# city_name         Chandrakona
# country_name      None
# raw_description   @IndianExpress When our beautiful earth will independent from this such types of terrorist attack??😖😖
# None
# datetime_happened None
# datetime_reported 1511647867.0
# longitude         None
# lattitude         None
# type              EVENT_TYPE.TERRORIST_ATTACK
# airport_id        None
# city_name         North West
# country_name      None
# raw_description   @Mungo_5 @JoeBloggs74 @BBCNWT Slightly different one was a terrorist attack one was a building fire !
# None
# datetime_happened None
# datetime_reported 1511647693.0
# longitude         None
# lattitude         None
# type              EVENT_TYPE.TERRORIST_ATTACK
# airport_id        None
# city_name         london
# country_name      None
# raw_description   Will a terrorist attack happen in London? - Quora https://t.co/wAb4IQjpJK
# None
# datetime_happened None
# datetime_reported 1511651208.0
# longitude         None
# lattitude         None
# type              EVENT_TYPE.TERRORIST_ATTACK
# airport_id        None
# city_name         
0
# longitude         None
# lattitude         None
# type              EVENT_TYPE.LABOUR_STRIKE
# airport_id        None
# city_name         ♥️🇪🇺♥️ Windsor
# country_name      None
# raw_description   @gwpurnell @MarkSpurs @TheStephenRalph @LibDems @UKLabour @YouTube long way to go yet. Labour will strike brexit do… https://t.co/ikDOabgX1Y
# None
# datetime_happened None
# datetime_reported 1511277125.0
# longitude         None
# lattitude         None
# type              EVENT_TYPE.LABOUR_STRIKE
# airport_id        None
# city_name         London
# country_name      None
# raw_description   How has labour organising changed? @jamie_woodcock, @CallumCant1 and @kellyjaderogers discuss resistance in the mod… https://t.co/kizHxNj7oC
# None
# datetime_happened None
# datetime_reported 1511272011.0
# longitude         None
# lattitude         None
# type              EVENT_TYPE.LABOUR_STRIKE
# airport_id        None
# city_name         York
# country_name      None
# raw_description   @A48percenter @PropertySpot @MikeH_PR I think you are giving Labour leadership too much credit....they don't strike… https://t.co/WCVdt5DKS9
# None
# datetime_happened None
# datetime_reported 1511256935.0
# longitude         None
# lattitude         None
# type              EVENT_TYPE.LABOUR_STRIKE
# airport_id        None
# city_name         None
# country_name      None
# raw_description   Looming coal strike could be averted - Business Day https://t.co/ObBRcGTnpX #coal
# None
# datetime_happened None
# datetime_reported 1511268726.0
# longitude         None
# lattitude         None
# type              EVENT_TYPE.LABOUR_STRIKE
# airport_id        None
# city_name         None
# country_name      None
# raw_description   RT "RT Gidi_Traffic: Kofi_Bartels DanaAir MMA2Bicourtney "Kofi_Bartels: So there's a strike by labour (United Labou… https://t.co/HOY0vWEAbS
# None
# datetime_happened None
# datetime_reported 1511268678.0
# longitude         None
# lattitude         None
# type              EVENT_TYPE.LABOUR_STRIKE
# airport_id        None
# city_name         Lekki
# country_name      None
# raw_description   RT "RT Gidi_Traffic: Kofi_Bartels DanaAir MMA2Bicourtney "Kofi_Bartels: So there's a strike by labour (United Labou… https://t.co/uWMnSMuTCn
# None
# datetime_happened None
# datetime_reported 1511268551.0
# longitude         None
# lattitude         None
# type              EVENT_TYPE.LABOUR_STRIKE
# airport_id        None
# city_name         None
# country_name      None
# raw_description   RT "RT Gidi_Traffic: Kofi_Bartels DanaAir MMA2Bicourtney "Kofi_Bartels: So there's a strike by labour (United Labou… https://t.co/CVXf2ChIJF
# None
# datetime_happened None
# datetime_reported 1511239699.0
# longitude         None
# lattitude         None
# type              EVENT_TYPE.LABOUR_STRIKE
# airport_id        None
# city_name         None
# country_name      None
# raw_description   RT"RT Gidi_Traffic: Kofi_Bartels DanaAir MMA2Bicourtney "Kofi_Bartels: So there's a strike by labour (United Labour… https://t.co/6p1ld6G6HZ
# None
# datetime_happened None
# datetime_reported 1511268448.0
# longitude         None
# lattitude         None
# type              EVENT_TYPE.LABOUR_STRIKE
# airport_id        None
# city_name         None
# country_name      None
# raw_description   RT "RT Gidi_Traffic: Kofi_Bartels DanaAir MMA2Bicourtney "Kofi_Bartels: So there's a strike by labour (United Labou… https://t.co/2X3P7OxnB9
# None
# datetime_happened None
# datetime_reported 1511268388.0
# longitude         None
# lattitude         None
# type              EVENT_TYPE.LABOUR_STRIKE
# airport_id        None
# city_name         None
# country_name      None
# raw_description   #Union Canada : College faculty return to work after legislation ends 5-week strike https://t.co/Lcs37odG6M
# None
# datetime_happened None
# datetime_reported 1511268115.0
# longitude         None
# lattitude         None
# type              EVENT_TYPE.LABOUR_STRIKE
# airport_id        None
# city_name         None
# country_name      None
# raw_description   @adampayne26 What would be the point? Under Labour trains would be out on strike most of time...
# None
# datetime_happened None
# datetime_reported 1511267521.0
# longitude         None
# lattitude         None
# type              EVENT_TYPE.LABOUR_STRIKE
# airport_id        None
# city_name         London
# country_name      None
# raw_description   Students @FanshaweCollege are back to class this morning after a five-week strike. Will they harbour any resentment… https://t.co/WibzQl9RmW
# None
# datetime_happened None
# datetime_reported 1511265920.0
# longitude         None
# lattitude         None
# type              EVENT_TYPE.LABOUR_STRIKE
# airport_id        None
# city_name         London
# country_name      None
# raw_description   Those of us who ran companies in. 1950s &amp; '70s don't want a return to either - especially not Labour's power-cut strike-ridden '70s!
# None
# datetime_happened None
# datetime_reported 1511236272.0
# longitude         None
# lattitude         None
# type              EVENT_TYPE.LABOUR_STRIKE
# airport_id        None
# city_name         global
# country_name      None
# raw_description   Looming coal strike could be averted https://t.co/XEwm50yoTY #SouthAfrica
# None
# datetime_happened None
# datetime_reported 1511268588.0
# longitude         None
# lattitude         None
# type              EVENT_TYPE.LABOUR_STRIKE
# airport_id        None
# city_name         Everywhere
# country_name      None
# raw_description   @Kofi_Bartels @DanaAir @MMA2Bicourtney "@Kofi_Bartels: So there's a strike by labour (United Labour Congress) over… https://t.co/7esPqTO9QN
# None
# datetime_happened None
# datetime_reported 1511271970.0
# longitude         None
# lattitude         None
# type              EVENT_TYPE.LABOUR_STRIKE
# airport_id        None
# city_name         Johannesburg
# country_name      None
# raw_description   Coal sector strike in balance as NUM weighs new Chamber wage offer https://t.co/C7mFiwIHEu #NUM #coalstrike
# None
# datetime_happened None
# datetime_reported 1511264721.0
# longitude         None
# lattitude         None
# type              EVENT_TYPE.LABOUR_STRIKE
# airport_id        None
# city_name         
0
# longitude         None
# lattitude         None
# type              EVENT_TYPE.LABOUR_STRIKE
# airport_id        None
# city_name         Mumbai
# country_name      None
# raw_description   @hcmariwala @BalakrishnanR Let it reach India and then we can start strike against it saying it will remove farm la… https://t.co/rVxcsK98Rh
# None
# datetime_happened None
# datetime_reported 1511196322.0
# longitude         None
# lattitude         None
# type              EVENT_TYPE.LABOUR_STRIKE
# airport_id        None
# city_name         None
# country_name      None
# raw_description   Warren Kinsella is out of favour with Liberals because he backed right wing leadership candidate Sandra Poopoo.  No… https://t.co/xdHodltQNU
# None
# datetime_happened None
# datetime_reported 1511193912.0
# longitude         None
# lattitude         None
# type              EVENT_TYPE.LABOUR_STRIKE
# airport_id        None
# city_name         Edmonton
# country_name      None
# raw_description   After months of negotiations, the union finally reached a deal with the HRWC in March 2012, avoiding a strike. This… https://t.co/QYPYCMM8vJ
# None

# %%
make_post('FAKE NEWS AGENCY big terrorist attack happened in SVO, Moscow right now')
make_post('FAKE NEWS AGENCY big terrorist attack happened in SVO, Moscow right now')

# %%
api.GetSearch(raw_query='q=labour+strike')
# Out:
# [Status(ID=934528382708088833, ScreenName=LabourStartCanE, Created=Sat Nov 25 21:05:03 +0000 2017, Text='QC: Tentative deal reached at CEZinc refinery in Salaberry-de-Valleyfield, ending strike that started on 12 Feb-CLR https://t.co/P11jivkx9e'),
#  Status(ID=934516384536686592, ScreenName=bonlime, Created=Sat Nov 25 20:17:23 +0000 2017, Text="What????? \n labour strike happened today at my home airport!\nit's a joke if you want to know"),
#  Status(ID=934507697176829953, ScreenName=bonlime, Created=Sat Nov 25 19:42:51 +0000 2017, Text='Again and again labour strike happened today at my home airport!'),
#  Status(ID=934493888710168579, ScreenName=EtonTaxDodger, Created=Sat Nov 25 18:47:59 +0000 2017, Text='@daviesneil275 @MidWalesMike @theresa_may General Strike and civil disobedience needs to  be discussed and acted on… https://t.co/d9RnV1CY9Y'),
#  Status(ID=934489949252083713, ScreenName=bonlime, Created=Sat Nov 25 18:32:20 +0000 2017, Text='haha labour strike happened today at my home MSK'),
#  Status(ID=934472927814340609, ScreenName=JohnDor25439820, Created=Sat Nov 25 17:24:42 +0000 2017, Text='@wittonlodge @ErdingtonTories @Lovell_UK @BhamCityCouncil Nothing at all to do with the labour council then, unlike the bin strike.'),
#  Status(ID=934470093811191808, ScreenName=_KatieVL, Created=Sat Nov 25 17:13:26 +0000 2017, Text='RT @cupe3902: CUPE says the key issue is how post-secondary institutions relay on “precarious labour,” with sessional lecturers... https://…'),
#  Status(ID=934468800476532737, ScreenName=williamshankly, Created=Sat Nov 25 17:08:18 +0000 2017, Text='RT @blackyellowbrd: #UprisingOfThe20000\nNovember 23, 1909.\n20,000 women went on strike in the New York garment industry. After 11 weeks the…'),
#  Status(ID=934449162011082752, ScreenName=LDEWawa, Created=Sat Nov 25 15:50:16 +0000 2017, Text='RT @OFLabour: Strike appeals draw donations from unions and labour councils across the province. #solidarity with striking workers, Black L…'),
#  Status(ID=934439789255974913, ScreenName=PlutoPress, Created=Sat Nov 25 15:13:01 +0000 2017, Text='How has labour organising changed? @jamie_woodcock, @CallumCant1 and @kellyjaderogers discuss resistance in the mod… https://t.co/4r0WZ2My9f'),
#  Status(ID=934435321525276673, ScreenName=labour_zone, Created=Sat Nov 25 14:55:16 +0000 2017, Text='RT @BBCEngland: Workers involved in a three-month bin strike which saw rubbish piled high on the streets of Birmingham have agreed to end t…'),
#  Status(ID=934435058307555328, ScreenName=ASK_des, Created=Sat Nov 25 14:54:13 +0000 2017, Text='RT @CleaverGavin: @ASK_des Yep, vote Labour for Sharia Law, including public stonings &amp; eating your pet when the food runs out. Forget work…'),
#  Status(ID=934434987532791810, ScreenName=CleaverGavin, Created=Sat Nov 25 14:53:56 +0000 2017, Text='@Czakal Yep, vote Labour for Sharia Law, including public stonings &amp; eating your pet when the food runs out. Forget… https://t.co/MSSfTvFfZa'),
#  Status(ID=934434873095413761, ScreenName=CleaverGavin, Created=Sat Nov 25 14:53:29 +0000 2017, Text='@stedanchick Yep, vote Labour for Sharia Law, including public stonings &amp; eating your pet when the food runs out. F… https://t.co/RQL8QrMFvP'),
#  Status(ID=934434374199758848, ScreenName=tim190266, Created=Sat Nov 25 14:51:30 +0000 2017, Text='@Jim_Watford I have far better memories January off school because the oil tanker drivers were on strike ..brillian… https://t.co/cFXa2B1zQv')]

# %%
pp.pprint(all_res[1][0].AsDict())
# Out:
# {   'created_at': 'Sat Nov 25 18:32:20 +0000 2017',
#     'hashtags': [],
#     'id': 934489949252083713,
#     'id_str': '934489949252083713',
#     'lang': 'en',
#     'place': {   'attributes': {},
#                  'bounding_box': {   'coordinates': [   [   [   24.78281,
#                                                                 60.021032],
#                                                             [   25.2544364,
#                                                                 60.021032],
#                                                             [   25.2544364,
#                                                                 60.2979104],
#                                                             [   24.78281,
#                                                                 60.2979104]]],
#                                      'type': 'Polygon'},
#                  'contained_within': [],
#                  'country': 'Finland',
#                  'country_code': 'FI',
#                  'full_name': 'Helsinki, Finland',
#                  'id': '5ef832bb704339b0',
#                  'name': 'Helsinki',
#                  'place_type': 'city',
#                  'url': 'https://api.twitter.com/1.1/geo/id/5ef832bb704339b0.json'},
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web '
#               'Client</a>',
#     'text': 'haha labour strike happened today at my home MSK',
#     'urls': [],
#     'user': {   'created_at': 'Sun Aug 26 14:20:44 +0000 2012',
#                 'default_profile': True,
#                 'description': 'Именной Стипендиат Правительства Москвы '
#                                '#followme',
#                 'favourites_count': 1,
#                 'followers_count': 977,
#                 'friends_count': 2822,
#                 'geo_enabled': True,
#                 'id': 782531360,
#                 'lang': 'ru',
#                 'listed_count': 2,
#                 'location': 'Москва, Россия',
#                 'name': 'Эмиль',
#                 'profile_background_color': 'C0DEED',
#                 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                 'profile_image_url': 'http://pbs.twimg.com/profile_images/667072827749609472/EIgE842d_normal.jpg',
#                 'profile_link_color': '1DA1F2',
#                 'profile_sidebar_fill_color': 'DDEEF6',
#                 'profile_text_color': '333333',
#                 'screen_name': 'bonlime',
#                 'statuses_count': 20,
#                 'time_zone': 'Karachi',
#                 'utc_offset': 18000},
#     'user_mentions': []}
